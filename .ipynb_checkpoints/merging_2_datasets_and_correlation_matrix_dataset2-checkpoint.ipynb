# %%
from pybootnet import *

# %%
# Load the ARG and MAG feature tables 
featuretable1 = pd.read_csv("/Users/nive/Documents/BMI_Project/TJ_River_Dataset2/ARG_rclr_dataset2_with_column_names.csv")
featuretable2 = pd.read_csv("/Users/nive/Documents/BMI_Project/TJ_River_Dataset2/MAG_rclr_dataset2_with_column_names.csv")

# %%
#Clean SampleID column to merge correctly
for df in [featuretable1, featuretable2]:
    df['SampleID'] = df['SampleID'].str.strip()
    
# Merging two feature tables
def merge_diff_networks(featuretable1, featuretable2):
    # First extracting the column names from each feature table, excluding SampleID
    featuretable1_columns_names = []
    for col in featuretable1.columns:
        if col != 'SampleID':
            featuretable1_columns_names.append(col)
            #print("Dataset1 features:", featuretable1_columns_names)

    featuretable2_columns_names = []
    for col in featuretable2.columns:
        if col != 'SampleID':
            featuretable2_columns_names.append(col)
            #print("Dataset2 features:", featuretable2_columns_names)

    # Next, merging the two feature tables using SampleID as the joining column
    merged_data = pd.merge(featuretable1, featuretable2, on='SampleID', how='inner')
    
    merged_data["Category"] = "TJ_River"
    cols = merged_data.columns.tolist()
    cols = ["SampleID", "Category"] + [c for c in merged_data.columns if c not in ["SampleID", "Category"]]
    merged_data = merged_data[cols]
    

    return featuretable1_columns_names, featuretable2_columns_names, merged_data

# %%
# Call the merge function
dataset1_feature_names, dataset2_feature_names, merged_data = merge_diff_networks(featuretable1,featuretable2)

# %%
# Save merged dataset
merged_data.to_csv(
    "/Users/nive/Documents/BMI_Project/TJ_River_Dataset2/merged_ARGs_CDS_and_MAG_featuretable.tsv",
    sep="\t",
    index=False
)

# %%
merged_data = pd.read_csv('/Users/nive/Documents/BMI_Project/TJ_River_Dataset2/merged_ARGs_CDS_and_MAG_featuretable.tsv', sep="\t")
merged_data
# Out:
#    SampleID  Category   tet(47)  ANT(9)-Ib       lin    DHA-31  OXA-1163  \
# 0      1_S6  TJ_River -0.373398  -0.373398 -0.373398 -0.373398 -0.373398
# 1      3_S8  TJ_River -2.783324  -2.783324 -2.783324 -2.783324  7.931094
# 2      4_S9  TJ_River -2.614826  -2.614826 -2.614826 -2.614826  8.318281
# 3     5_S10  TJ_River -2.340236  -2.340236 -2.340236 -2.340236  8.844186
# 4     6_S11  TJ_River -0.905931  -0.905931 -0.905931 -0.905931  7.947734
# 5     7_S12  TJ_River -2.590380  -2.590380 -2.590380 -2.590380  8.006255
# 6     8_S13  TJ_River -1.579769  -1.579769 -1.579769 -1.579769  7.525210
# 7     9_S14  TJ_River -2.493765  -2.493765 -2.493765 -2.493765  7.632866
# 8    10_S15  TJ_River -1.009859  -1.009859 -1.009859 -1.009859  7.689655
# 9    12_S16  TJ_River -0.101345  -0.101345 -0.101345 -0.101345 -0.101345
# 10   13_S17  TJ_River -0.996268  -0.996268 -0.996268 -0.996268 -0.996268
# 11   14_S18  TJ_River -0.046052  -0.046052 -0.046052 -0.046052 -0.046052
#
#     ANT(4')-Ia   KPC-172     BJP-1  ...  \
# 0    -0.373398 -0.373398 -0.373398  ...
# 1     7.014803  5.510725 -2.783324  ...
# 2     7.428423 -2.614826 -2.614826  ...
# 3     6.513430 -2.340236 -2.340236  ...
# 4    -0.905931 -0.905931 -0.905931  ...
# 5     7.408418 -2.590380 -2.590380  ...
# 6     6.426598 -1.579769 -1.579769  ...
# 7    -2.493765 -2.493765 -2.493765  ...
# 8     7.689655 -1.009859 -1.009859  ...
# 9    -0.101345 -0.101345 -0.101345  ...
# 10   -0.996268 -0.996268 -0.996268  ...
# 11   -0.046052 -0.046052 -0.046052  ...
#
#     d__Bacteria;p__Pseudomonadota;c__Alphaproteobacteria;o__Rhizobiales;f__Rhizobiaceae;g__Allorhizobium;s__  \
# 0                                            2.984680
# 1                                            2.203076
# 2                                           -0.181613
# 3                                            1.820070
# 4                                           -2.648252
# 5                                            1.229981
# 6                                           -2.912853
# 7                                            1.219715
# 8                                           -2.836821
# 9                                           -0.801943
# 10                                           3.268781
# 11                                          -2.691834
#
#     d__Bacteria;p__Verrucomicrobiota;c__Verrucomicrobiae;o__Opitutales;f__Coraliomargaritaceae;g__Lentimonas;s__.1  \
# 0                                            3.629690
# 1                                           -1.991808
# 2                                           -0.464556
# 3                                           -2.000477
# 4                                            1.213176
# 5                                           -2.120876
# 6                                            0.235170
# 7                                           -1.941694
# 8                                            1.208015
# 9                                           -0.801943
# 10                                          -1.361744
# 11                                           0.711984
#
#     d__Bacteria;p__Pseudomonadota;c__Gammaproteobacteria;o__Pseudomonadales;f__Azotimanducaceae_A;g__;s__  \
# 0                                            2.981242
# 1                                           -1.991808
# 2                                           -0.123431
# 3                                           -2.000477
# 4                                            1.266259
# 5                                           -2.120876
# 6                                            0.052822
# 7                                           -1.941694
# 8                                            1.047160
# 9                                           -0.801943
# 10                                           2.223174
# 11                                           0.879972
#
#     Unclassified Bacteria.37  Unclassified Bacteria.38  \
# 0                   4.533333                  4.498688
# 1                  -1.991808                 -1.991808
# 2                  -3.168231                 -3.168231
# 3                  -2.000477                 -2.000477
# 4                  -2.648252                 -2.648252
# 5                  -2.120876                 -2.120876
# 6                  -2.912853                 -2.912853
# 7                  -1.941694                 -1.941694
# 8                  -2.836821                 -2.836821
# 9                  -0.801943                 -0.801943
# 10                 -1.361744                 -1.361744
# 11                 -2.691834                 -2.691834
#
#     Unclassified Bacteria.39  \
# 0                   4.498446
# 1                  -1.991808
# 2                  -3.168231
# 3                  -2.000477
# 4                  -2.648252
# 5                  -2.120876
# 6                  -2.912853
# 7                  -1.941694
# 8                  -2.836821
# 9                  -0.801943
# 10                 -1.361744
# 11                 -2.691834
#
#     d__Bacteria;p__Actinomycetota;c__Actinomycetes;o__Actinomycetales;f__Microbacteriaceae;g__JALRLI01;s__.1  \
# 0                                            4.480609
# 1                                           -1.991808
# 2                                           -3.168231
# 3                                           -2.000477
# 4                                           -2.648252
# 5                                           -2.120876
# 6                                           -2.912853
# 7                                           -1.941694
# 8                                           -2.836821
# 9                                           -0.801943
# 10                                          -1.361744
# 11                                          -2.691834
#
#     d__Bacteria;p__Cyanobacteriota;c__Cyanobacteriia;o__Cyanobacteriales;f__PCC-6304;g__Planktothricoides;s__  \
# 0                                            4.429545
# 1                                           -1.991808
# 2                                           -3.168231
# 3                                           -2.000477
# 4                                           -2.648252
# 5                                           -2.120876
# 6                                           -2.912853
# 7                                           -1.941694
# 8                                           -2.836821
# 9                                           -0.801943
# 10                                          -1.361744
# 11                                          -2.691834
#
#     d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Flavobacteriales;f__SAT41;g__;s__  \
# 0                                            4.203575
# 1                                           -1.991808
# 2                                           -3.168231
# 3                                           -2.000477
# 4                                           -2.648252
# 5                                           -2.120876
# 6                                           -2.912853
# 7                                           -1.941694
# 8                                           -2.836821
# 9                                           -0.801943
# 10                                          -1.361744
# 11                                          -2.691834
#
#     d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Flavobacteriales;f__CANHHI01;g__;s__
# 0                                            3.975052
# 1                                           -1.991808
# 2                                           -3.168231
# 3                                           -2.000477
# 4                                           -2.648252
# 5                                           -2.120876
# 6                                           -2.912853
# 7                                           -1.941694
# 8                                           -2.836821
# 9                                           -0.801943
# 10                                          -1.361744
# 11                                          -2.691834
#
# [12 rows x 467 columns]

# %%
#Create bootstrap replicates of the merged data
create_bootstrap = bootstrap_replicates(merged_data, 500)

# %%
# After merging the feature tables, create a correlatation matrix with the merged table
# Only interested in correlations between features from different tables, not within the same table
# Set any correlations between features within the same table equal to 0
# The return matrix should only contain values between features from different tables, while the remaining should be 0

def different_network_correlation_matrix(data_list, dataset1_feature_names, dataset2_feature_names):
    matrix_list = []

    for data in data_list:
        correlations = data.corr(method='spearman', numeric_only=True)

        # Set within dataset1 correlations to 0
        correlations.loc[dataset1_feature_names, dataset1_feature_names] = 0

        # Set within dataset2 correlations to 0
        correlations.loc[dataset2_feature_names, dataset2_feature_names] = 0

        # Keeping only dataset1/dataset2 correlations
        correlations.loc[dataset1_feature_names, dataset2_feature_names]

        matrix_list.append(correlations)

    return matrix_list

# %%
# Call the correlation function
matrix_list = different_network_correlation_matrix(
    create_bootstrap,
    dataset1_feature_names,
    dataset2_feature_names
)

# %%
# Save correlation matrices
matrix_list[0].to_csv(
    "/Users/nive/Documents/BMI_Project/TJ_River_Dataset2/correlation_matrix_ARGs_and_MAGs_dataset2.tsv",
    sep="\t"
)

# %%
#Create the network graph uaing the correlation matrix between ARGs and MAGs alone
build_network_graph(matrix_list, 0.8, title="TJ_dataset2_Correlation_Network_ARGs_and_MAGs")

# %%
#build only positive correlations
G=build_positive_network(matrix_list, 0.85, title="Positive Correlation Network between ARGs and MAGs - Dataset 2")
#Save the figure
plt.savefig("Positive_Correlation_Network_Dataset2.png", dpi=300, bbox_inches='tight')
#Get the nodes names
node_table = nodes_edges_table(G)
node_table.to_csv("all_network_nodes_dataset2_from_graph.csv", index=True)

# %%
TJ_River_stat = calculate_network_statistics(matrix_list, 0.85)

# %%
project_stats = {
    'TJ_River' : TJ_River_stat
}

# %%
analyze_network_statistics(project_stats, filename='TJ_River_Dataset2_stats.csv', project_name='TJ_River_Network')
# Out:
#                            TJ_River_mean  TJ_River_std
# Number of Edges                 3350.594      2526.446
# Number of Nodes                  308.246        67.917
# Average Degree Centrality          0.076         0.059
# Transitivity                       0.000         0.000
# Closeness Centrality               0.202         0.067
# Betweeness Centrality              0.004         0.003
# Density                            0.076         0.059
